# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishnasubash/gitstudy/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=int(input("enter third number:")
# Out:
#   File "/tmp/ipykernel_8501/1636511653.py", line 4
#     if a>b?a:b
#           ^
# SyntaxError: invalid syntax

# %%
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=int(input("enter third number:"))
largest=max(a,b,c)
print(largest)
# Out:
# enter first number:6
# enter second number:2
# enter third number:8
# 8

# %%
n=int(input("enter a number"))
i=1
while(i<=10):
  result=n*i
  print(n,"*",i,"=",result)
  i=i+1

# %%
n=int(input("enter a range"))
sum=0
for i in range (1,n+1):
  sum=sum+i
print("sum",sum)
# Out:
# enter a range5
# sum 15

# %%
n=int(input("enter a number"))
fact=1
for i in range(1,n+1):
  fact=fact*i
print("factorial is",fact)
# Out:
# enter a number5
# factorial is 120

# %%
s=input("enter string")
count=0
for ch in s:
  if ch in "aeiou":
    count=count+1
print("count of vowels is",count)
# Out:
# enter stringkrishna
# count of vowels is 2

# %%
s=input("enter a string")
rev=s[::-1]
print("reverse is",rev)
# Out:
# enter a stringkichu
# reverse is uhcik

# %%
s=input("enter a string")
rev=""
for ch in s:
  rev=ch+rev
print(rev)
# Out:
# enter a stringechu
# uhce

# %%
s=input("enter a word")
for ch in s:
  rev=s[::-1]
  if(rev==s):
    print("palindrome")
  else:
      print("not")
# Out:
# enter a wordsweet
# not
# not
# not
# not
# not
